# %%
import mysql.connector as sql

connection = sql.connect(
    host="localhost",
    user="root",
    password="root",
    # database="pukar"
)
print(connection)

# %%
# Create a Database Connection

cursor = connection.cursor()

# %%
# #Basic SQL Queries:
# Describe the different types of JOINs in SQL.
# What is the difference between WHERE and HAVING clauses?
# Write a SQL query to fetch the TOP 3 records from a table.
# Aggregation and Statistics:
# How do you calculate the average and median in SQL?
# Write a query to find the total number of records in each category using GROUP BY.
# Explain the use of aggregate functions like SUM(), COUNT(), MAX(), MIN(), and AVG().
# Complex Queries and Subqueries:
# Write a query to select all customers who purchased at least two different products on the same day.
# How would you find the second highest salary in a company?
# Describe a scenario where you would use a subquery. Can you give an example?
# Window Functions:
# What are window functions in SQL? Give examples of some common window functions.
# Write a SQL query to rank customers based on their purchase amounts within each region using a window function.
# Optimization and Performance:
# What are indexes and how can they improve query performance?
# Explain the impact of using JOINs on the performance of SQL queries.
# How can you optimize a slow-running query?
# Data Manipulation and ETL Processes:
# Write a SQL script to merge two tables.
# What are the best practices for ETL processes in SQL?
# How do you handle duplicate records in SQL?
# Real-World Scenarios and Problem Solving:
# Imagine you have a table of customer interactions. How would you extract insights about customer behavior over time?
# Discuss how you would use SQL to support A/B testing.
# How can SQL be used to handle large datasets efficiently in a data science context?

# %%
# Describe the different types of JOINs in SQL.

# There are four basic types of SQL joins: inner, left, right, and full. The easiest and most intuitive way to explain the difference between these four types is by using a Venn diagram, which shows all possible logical relations between data sets.
