# %%
import mysql.connector as sql

connection = sql.connect(
    host="localhost",
    user="root",
    password="root",
    database="pukar"
)
print(connection)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x00000263BBA76060>

# %%
# Create a Database

cursor = connection.cursor()

# %%
# SQL Contents:
# CREATE DATABASE pukar

# cursor.execute("CREATE DATABASE pukar")

# cursor.execute("SHOW DATABASES")
# for db in cursor:
#     print(db)


# Create a Table

# SQL Contents:
# CREATE TABLE users (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     name VARCHAR(100),
#     age INT
# )

# cursor.execute("CREATE TABLE users (id INT AUTO_INCREMENT PRIMARY KEY, name VARCHAR(100), age INT)")

# cursor.execute("SHOW TABLES")
# for table in cursor:
#     print(table)
