# %%
# Basic of Time and Space Complexity in Python

# Time Complexity
# Time complexity is a function describing the amount of time an algorithm takes in terms of the amount of input to the algorithm.
# It is commonly expressed using the big O notation, which suppresses constant factors and lower order terms.
# For example, the time complexity of a function that finds the maximum element in an unsorted list is O(n), where n is the number of elements in the list.

# Space Complexity
# Space complexity is a function describing the amount of memory (space) an algorithm takes in terms of the amount of input to the algorithm.
# It is commonly expressed using the big O notation, which suppresses constant factors and lower order terms.
# For example, the space complexity of a function that finds the maximum element in an unsorted list is O(1), because it only uses a constant amount of memory regardless of the size of the input.

# Example of Time and Space Complexity
# The following function finds the maximum element in an unsorted list using a linear search algorithm.
# The time complexity of this function is O(n), where n is the number of elements in the list.
# The space complexity of this function is O(1), because it only uses a constant amount of memory regardless of the size of the input.

def find_max(lst):
    max_val = lst[0]
    for val in lst:
        if val > max_val:
            max_val = val
    return max_val

# Time Complexity: O(n)
# Space Complexity: O(1)

# Example of Time and Space Complexity
# The following function finds the maximum element in an unsorted list using a linear search algorithm.
# The time complexity of this function is O(n), where n is the number of elements in the list.
# The space complexity of this function is O(n), because it creates a new list to store the maximum element.

def find_max(lst):
    max_val = lst[0]
    for val in lst:
        if val > max_val:
            max_val = val
    return [max_val]

# Time Complexity: O(n)
# Space Complexity: O(n)

# Example of Time and Space Complexity
# The following function finds the maximum element in an unsorted list using a linear search algorithm.
# The time complexity of this function is O(n^2), where n is the number of elements in the list.
# The space complexity of this function is O(1), because it only uses a constant amount of memory regardless of the size of the input.

def find_max(lst):
    for i in range(len(lst)):
        is_max = True
        for j in range(len(lst)):
            if lst[j] > lst[i]:
                is_max = False
                break
        if is_max:
            return lst[i]
        
# Time Complexity: O(n^2)
# Space Complexity: O(1)

# Example of Time and Space Complexity
# The following function finds the maximum element in an unsorted list using a linear search algorithm.
# The time complexity of this function is O(n), where n is the number of elements in the list.
# The space complexity of this function is O(n), because it creates a new list to store the maximum element.

def find_max(lst):
    max_val = lst[0]
    for val in lst:
        if val > max_val:
            max_val = val
    return [max_val]

# Time Complexity: O(n)
# Space Complexity: O(n)

# Example of Time and Space Complexity
# The following function finds the maximum element in an unsorted list using a linear search algorithm.
# The time complexity of this function is O(n), where n is the number of elements in the list.
# The space complexity of this function is O(1), because it only uses a constant amount of memory regardless of the size of the input.

def find_max(lst):
    max_val = lst[0]
    for val in lst:
        if val > max_val:
            max_val = val
    return max_val

# Time Complexity: O(n)
# Space Complexity: O(1)

# Example of Time and Space Complexity
# The following function finds the maximum element in an unsorted list using a linear search algorithm.
# The time complexity of this function is O(n), where n is the number of elements in the list.
# The space complexity of this function is O(n), because it creates a new list to store the maximum element.

def find_max(lst):
    max_val = lst[0]
    for val in lst:
        if val > max_val:
            max_val = val
    return [max_val]

# Time Complexity: O(n)
# Space Complexity: O(n)
