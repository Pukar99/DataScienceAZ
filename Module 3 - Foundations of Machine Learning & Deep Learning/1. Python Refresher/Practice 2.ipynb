# %%
# Basic Syntax and Data Types in Python:

# %%
# 1. Variables and Data Types:
# Variables are used to store values. A variable is created the moment you first assign a value to it.
# Python has five standard data types −
# Numbers, String, List, Tuple, Dictionary

# Numbers: Python supports integers, floating point numbers and complex numbers.
num1 = 10
num2 = 20.5
num3 = 3 + 4j
print(num1, num2, num3)

# String: Strings in Python are identified as a contiguous set of characters represented in the quotation marks.
str1 = 'Hello World!'
str2 = "Python Programming"
print(str1, str2)

# List: Lists are the most versatile of Python's compound data types. A list contains items separated by commas and enclosed within square brackets ([]).
list1 = [10, 20, 30, 40, 50]
list2 = ['apple', 'banana', 'cherry']
print(list1, list2)

# Tuple: A tuple is another sequence data type that is similar to the list. A tuple consists of a number of values separated by commas.
tuple1 = (10, 20, 30, 40, 50)
tuple2 = ('apple', 'banana', 'cherry')
print(tuple1, tuple2)

# Dictionary: Python's dictionaries are kind of hash table type. They work like associative arrays or hashes found in Perl and consist of key-value pairs.
dict1 = {'name': 'John', 'age': 25, 'city': 'New York'}
print(dict1)
# Out:
# 10 20.5 (3+4j)
# Hello World! Python Programming
# [10, 20, 30, 40, 50] ['apple', 'banana', 'cherry']
# (10, 20, 30, 40, 50) ('apple', 'banana', 'cherry')
# {'name': 'John', 'age': 25, 'city': 'New York'}

# %%
# 2. Operators:
# Operators are used to perform operations on variables and values.
# Python divides the operators in the following groups:
# Arithmetic operators, Assignment operators, Comparison operators, Logical operators, Identity operators, Membership operators, Bitwise operators

# Arithmetic operators: Arithmetic operators are used with numeric values to perform common mathematical operations.
a = 10
b = 20
print(a + b)  # Addition
print(a - b)  # Subtraction
print(a * b)  # Multiplication
print(a / b)  # Division
print(a % b)  # Modulus
print(a ** b)  # Exponentiation
print(a // b)  # Floor division

# Assignment operators: Assignment operators are used to assign values to variables.
a = 10
a += 5  # a = a + 5
print(a)

# Comparison operators: Comparison operators are used to compare two values.
a = 10
b = 20
print(a == b)  # Equal
print(a != b)  # Not equal
print(a > b)  # Greater than
print(a < b)  # Less than
print(a >= b)  # Greater than or equal to
print(a <= b)  # Less than or equal to

# Logical operators: Logical operators are used to combine conditional statements.
a = 10
b = 20
print(a > 5 and b < 30)  # and
print(a > 5 or b < 30)  # or
print(not(a > 5 and b < 30))  # not

# Identity operators: Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location.
a = 10
b = 20
print(a is b)  # is
print(a is not b)  # is not

# Membership operators: Membership operators are used to test if a sequence is presented in an object.
list1 = [10, 20, 30, 40, 50]
print(10 in list1)  # in
print(60 not in list1)  # not in

# Bitwise operators: Bitwise operators are used to compare (binary) numbers.
a = 10
b = 20
print(a & b)  # AND
print(a | b)  # OR
print(a ^ b)  # XOR
print(~a)  # NOT
print(a << 2)  # Zero fill left shift
print(a >> 2)  # Signed right shift
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 100000000000000000000
# 0
# 15
# False
# True
# False
# True
# False
# True
# True
# True
# False
# False
# True
# True
# True
# 0
# 30
# 30
# -11
# 40
# 2

# %%
#3. Conditional Statements:
# Conditional statements are used to perform different actions based on different conditions.
# Python supports the following conditional statements:
# if, elif, else

# if statement: Use the if statement to execute a block of code, if the condition is True.
a = 10
b = 20
if a < b:
    print('a is less than b')
    
# elif statement: Use the elif statement to specify a new condition if the first condition is False.
a = 10
b = 20
if a > b:
    print('a is greater than b')
elif a < b:
    print('a is less than b')
    
# else statement: Use the else statement to execute a block of code, if the condition is False.
a = 10
b = 20
if a > b:
    print('a is greater than b')
elif a < b:
    print('a is less than b')
else:
    print('a is equal to b')
    
# Nested if statement: You can have if statements inside if statements, this is called nested if statements.
a = 10
if a > 0:
    if a % 2 == 0:
        print('a is a positive even number')
    else:
        print('a is a positive odd number')
else:
    print('a is a negative number')
    
# Short Hand If: If you have only one statement to execute, you can put it on the same line as the if statement.
a = 10
if a > 0: print('a is a positive number')

# Short Hand If ... Else: If you have only one statement to execute, one for if, and one for else, you can put it all on the same line.
a = 10
print('a is a positive number') if a > 0 else print('a is a negative number')

# And: The and keyword is a logical operator, and is used to combine conditional statements.
a = 10
b = 20
if a > 0 and b > 0:
    print('Both a and b are positive numbers')
    
# Or: The or keyword is a logical operator, and is used to combine conditional statements.
a = 10
b = 20
if a > 0 or b > 0:
    print('Either a or b is a positive number')
    
# Nested if-else: You can have if-else statements inside if-else statements, this is called nested if-else statements.
a = 10
if a > 0:
    if a % 2 == 0:
        print('a is a positive even number')
    else:
        print('a is a positive odd number')
else:
    print('a is a negative number')
    
# Pass: if statements cannot be empty, but if you for some reason have an if statement with no content, put in the pass statement to avoid getting an error.
a = 10
if a > 0:
    pass
# Out:
# a is less than b
# a is less than b
# a is less than b
# a is a positive even number
# a is a positive number
# a is a positive number
# Both a and b are positive numbers
# Either a or b is a positive number
# a is a positive even number

# %%
# 4. Loops:
# Python has two primitive loop commands:
# while loops, for loops

# while loop: With the while loop we can execute a set of statements as long as a condition is true.
i = 1
while i <= 5:
    print(i)
    i += 1
    
# break statement: With the break statement we can stop the loop even if the while condition is true.
i = 1
while i <= 5:
    print(i)
    if i == 3:
        break
    i += 1
    
# continue statement: With the continue statement we can stop the current iteration, and continue with the next.
i = 0
while i < 5:
    i += 1
    if i == 3:
        continue
    print(i)
    
# else statement: With the else statement we can run a block of code once when the condition no longer is true.
i = 1
while i <= 5:
    print(i)
    i += 1
else:
    print('i is no longer less than or equal to 5')
    
# for loop: A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).
list1 = [10, 20, 30, 40, 50]
for i in list1:
    print(i)
    
# range() function: To loop through a set of code a specified number of times, we can use the range() function.
for i in range(5):
    print(i)
    
# break statement: With the break statement we can stop the loop before it has looped through all the items.
list1 = [10, 20, 30, 40, 50]
for i in list1:
    print(i)
    if i == 30:
        break
    
# continue statement: With the continue statement we can stop the current iteration of the loop, and continue with the next.
list1 = [10, 20, 30, 40, 50]
for i in list1:
    if i == 30:
        continue
    print(i)
    
# else statement: With the else statement we can run a block of code once when the loop is finished.
list1 = [10, 20, 30, 40, 50]
for i in list1:
    print(i)
else:
    print('Loop is finished')
    
# Nested loops: A nested loop is a loop inside a loop.
list1 = ['apple', 'banana', 'cherry']
list2 = ['red', 'yellow', 'green']
for i in list1:
    for j in list2:
        print(i, j)
        
# pass statement: for loops cannot be empty, but if you for some reason have a for loop with no content, put in the pass statement to avoid getting an error.
for i in range(5):
    pass
# Out:
# 1
# 2
# 3
# 4
# 5
# 1
# 2
# 3
# 1
# 2
# 4
# 5
# 1
# 2
# 3
# 4
# 5
# i is no longer less than or equal to 5
# 10
# 20
# 30
# 40
# 50
# 0
# 1
# 2
# 3
# 4
# 10
# 20
# 30
# 10
# 20
# 40
# 50
# 10
# 20
# 30
# 40
# 50
# Loop is finished
# apple red
# apple yellow
# apple green
# banana red
# banana yellow
# banana green
# cherry red
# cherry yellow
# cherry green

# %%
# 5. Functions:
# A function is a block of code which only runs when it is called.
# You can pass data, known as parameters, into a function.
# A function can return data as a result.
# In Python a function is defined using the def keyword.
def my_function():
    print('Hello from a function')
    
my_function()

# Arguments: Information can be passed into functions as arguments.
def my_function(name):
    print('Hello', name)
    
my_function('John')

# Number of Arguments: By default, a function must be called with the correct number of arguments. Meaning that if your function expects 2 arguments, you have to call the function with 2 arguments, not more, and not less.
def my_function(name, age):
    print(name, 'is', age, 'years old')
    
my_function('John', 25)

# Arbitrary Arguments, *args: If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
def my_function(*names):
    print('The youngest child is', names[2])
    
my_function('John', 'Jane', 'Jake')

# Keyword Arguments: You can also send arguments with the key = value syntax.
def my_function(name, age):
    print(name, 'is', age, 'years old')
my_function(age=25, name='John')

# Arbitrary Keyword Arguments, **kwargs: If you do not know how many keyword arguments that will be passed into your function, add two asterisk: ** before the parameter name in the function definition.
def my_function(**names):
    print('The youngest child is', names['child3'])
my_function(child1='John', child2='Jane', child3='Jake')

# Default Parameter Value: If we call the function without argument, it uses the default value.
def my_function(country='Norway'):
    print('I am from', country)
my_function('Sweden')
my_function('India')
my_function()

# Passing a List as an Argument: You can send any data types of argument to a function (string, number, list, dictionary etc.), and it will be treated as the same data type inside the function.
def my_function(food):
    for i in food:
        print(i)
fruits = ['apple', 'banana', 'cherry']
my_function(fruits)

# Return Values: To let a function return a value, use the return statement.
def my_function(x):
    return 5 * x
print(my_function(3))

# The pass Statement: function definitions cannot be empty, but if you for some reason have a function definition with no content, put in the pass statement to avoid getting an error.
def my_function():
    pass
# Out:
# Hello from a function
# Hello John
# John is 25 years old
# The youngest child is Jake
# John is 25 years old
# The youngest child is Jake
# I am from Sweden
# I am from India
# I am from Norway
# apple
# banana
# cherry
# 15

# %%
# 6. Classes and Objects:
# Python is an object oriented programming language.
# Almost everything in Python is an object, with its properties and methods.
# A Class is like an object constructor, or a "blueprint" for creating objects.
# To create a class, use the keyword class.
# The __init__() function is called automatically every time the class is being used to create a new object.
# All classes have a function called __init__(), which is always executed when the class is being initiated.
# Use the __init__() function to assign values to object properties, or other operations that are necessary to do when the object is being created.
# Objects can also contain methods. Methods in objects are functions that belong to the object.
# The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.
# It does not have to be named self, you can call it whatever you like, but it has to be the first parameter of any function in the class.
# Use the words mysillyobject and abc instead of self.
# You can modify properties on objects like this: objectname.property = newvalue.
# You can delete properties on objects by using the del keyword.
# You can delete objects by using the del keyword.
# The pass statement: class definitions
class MyClass:
    x = 5
p1 = MyClass()

# The __init__() function: class definitions
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
p1 = Person('John', 25)
print(p1.name)
print(p1.age)

# Object Methods: class definitions
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def myfunc(self):
        print('Hello my name is', self.name)
p1 = Person('John', 25)
p1.myfunc()

# The self Parameter: class definitions
class Person:
    def __init__(mysillyobject, name, age):
        mysillyobject.name = name
        mysillyobject.age = age
    def myfunc(abc):
        print('Hello my name is', abc.name)
p1 = Person('John', 25)
p1.myfunc()

# Modify Object Properties: class definitions
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
p1 = Person('John', 25)
p1.age = 26
print(p1.age)

# Delete Object Properties: class definitions
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
p1 = Person('John', 25)
del p1.age
# print(p1.age)

# Delete Objects: class definitions
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
p1 = Person('John', 25)
del p1
# print(p1)

# The pass Statement: class definitions
class Person:
    pass
# Out:
# John
# 25
# Hello my name is John
# Hello my name is John
# 26

# %%
# 7. Inheritance:
# Inheritance allows us to define a class that inherits all the methods and properties from another class.

# Parent class: The class being inherited from is called the parent class.
class Person:
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname
    def printname(self):
        print(self.firstname, self.lastname)
x = Person('John', 'Doe')
x.printname()

# Child class: The class that inherits from another class is called the child class.
class Student(Person):
    pass
x = Student('Mike', 'Olsen')    
x.printname()

# Add the __init__() function: class definitions
class Student(Person):
    def __init__(self, fname, lname):
        Person.__init__(self, fname, lname)
x = Student('Mike', 'Olsen')
x.printname()

# Use the super() Function: class definitions
class Student(Person):
    def __init__(self, fname, lname):
        super().__init__(fname, lname)
x = Student('Mike', 'Olsen')
x.printname()

# Add Properties: class definitions
class Student(Person):
    def __init__(self, fname, lname, year):
        super().__init__(fname, lname)
        self.graduationyear = year
x = Student('Mike', 'Olsen', 2019)
print(x.graduationyear)

# Add Methods: class definitions
class Student(Person):
    def __init__(self, fname, lname, year):
        super().__init__(fname, lname)
        self.graduationyear = year
    def welcome(self):
        print('Welcome', self.firstname, self.lastname, 'to the class of', self.graduationyear)
x = Student('Mike', 'Olsen', 2019)
x.welcome()
# Out:
# John Doe
# Mike Olsen
# Mike Olsen
# Mike Olsen
# 2019
# Welcome Mike Olsen to the class of 2019

# %%
# 8. Modules:
# Consider a module to be the same as a code library.
# A file containing a set of functions you want to include in your application.
# To create a module just save the code you want in a file with the file extension .py.
# Now you can use the module we just created, by using the import statement.
# When using a function from a module, use the syntax: module_name.function_name.
# You can create an alias when you import a module, by using the as keyword.
# You can choose to import only parts from a module, by using the from keyword.
# When importing using the from keyword, do not use the module name when referring to elements in the module.
# You can use the dir() function to list all the functions in a module.
# You can use the help() function to get information about a function.
# The dir() function: module definitions

# import mymodule
# mymodule.greeting('John')

# # Import From Module: module definitions
# import mymodule
# a = mymodule.person1['age']
# print(a)

# # Renaming a Module: module definitions
# import mymodule as mx
# mx.greeting('John')

# Built-in Modules: module definitions
import platform
x = platform.system()
print(x)

# Using the dir() Function: module definitions
import platform
x = dir(platform)
print(x)

# # Import From Module: module definitions

# from mymodule import person1
# print(person1['age'])
# Out:
# Windows
# ...

# %%
# 9. File Handling:
# File handling is an important part of any web application.
# Python has several functions for creating, reading, updating, and deleting files.
# The key function for working with files in Python is the open() function.
# The open() function takes two parameters; filename, and mode.
# There are four different methods (modes) for opening a file:
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
# "a" - Append - Opens a file for appending, creates the file if it does not exist
# "w" - Write - Opens a file for writing, creates the file if it does not exist
# "x" - Create - Creates the specified file, returns an error if the file exists
# In addition you can specify if the file should be handled as binary or text mode
# "t" - Text - Default value. Text mode
# "b" - Binary - Binary mode (e.g. images)
# To open a file for reading it is enough to specify the name of the file.
# To open the file, use the built-in open() function.
# The open() function returns a file object, which has a read() method for reading the content of the file.
# The file can be closed using the close() method.
# It is a good practice to always close the file when you are done with it.
# The with statement is used to wrap the execution of a block of code.
# This way, you don't have to close the file when you are done with it.
# The read() method returns the specified number of bytes from the file.
# By default the read() method returns the whole text.
# You can return one line by using the readline() method.
# By looping through the lines of the file, you can read the whole file, line by line.
# The write() method is used to write text to the file.
# The write() method returns the number of bytes written to the file.
# The append() method is used to append text to the file.
# The append() method returns the number of bytes written to the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will overwrite the entire file.
# The a mode will append to the end of the file.
# The w mode will create a file, if it does not exist.
# The x mode will create a file, returns an error if the file exist.
# The a mode will create a file, if it does not exist.
# The a mode will create a file, if it does not exist.

f= open("demofile.txt", "r")
print(f.read())

f= open("demofile.txt", "r")
print(f.read(5))

f= open("demofile.txt", "r")
print(f.readline())

f= open("demofile.txt", "r")
for x in f:
    print(x)
    
f= open("demofile.txt", "a")
f.write("Now the file has more content!")

f= open("demofile.txt", "r")
print(f.read())

f= open("demofile.txt", "w")
f.write("Woops! I have deleted the content!")

f= open("demofile.txt", "r")
print(f.read())

f= open("demofile.txt", "x")
f.write("Woops! I have deleted the content!")

f= open("demofile.txt", "r")
print(f.read())

f= open("demofile.txt", "a")
f.write("Now the file has more content!")

# %%
# 10. Exceptions:
# When an error occurs, or exception as we call it, Python will normally stop and generate an error message.
# These exceptions can be handled using the try statement.
# The try block lets you test a block of code for errors.
# The except block lets you handle the error.
# The finally block lets you execute code, regardless of the result of the try- and except blocks.
# When an error occurs, or exception as we call it, Python will normally stop and generate an error message.
# These exceptions can be handled using the try statement.
# The try block lets you test a block of code for errors.
# The except block lets you handle the error.
# The finally block lets you execute code, regardless of the result of the try- and except blocks.
# The try block will generate an exception, because x is not defined.
# The except block will handle the exception, and print a message and continue with the code.
# The try block will generate an exception, because x is not defined.
# The except block will handle the exception and print a message.
# Since the try block raises an error, the except block will be executed.
# Without the try block, the program will crash and raise an error.
# The finally block, if specified, will be executed regardless if the try block raises an error or not.
# The finally block gets executed no matter if the try block raises any exceptions or not.
# The finally block will be executed no matter if the try block raises an error or not.
# The finally block will be executed no matter if the try block raises an error or not.
# The try block does not raise any errors, so the else block will be executed.

try:
    print(x)
except:
    print('An exception occurred')
    
try:
    print(x)
except NameError:
    print('Variable x is not defined')
except:
    print('Something else went wrong')
    
try:
    print('Hello')
except:
    print('Something went wrong')
else:
    print('Nothing went wrong')
    
try:
    print(x)
except:
    print('Something went wrong')
finally:
    print('The try except is finished')
    
try:
    print('Hello')
except:
    print('Something went wrong')
else:
    print('Nothing went wrong')
finally:
    print('The try except is finished')
    
try:
    print(x)
except:
    print('Something went wrong')
finally:
    print('The try except is finished')
    
try:
    f = open('demofile.txt')
    f.write('Lorum Ipsum')
except:
    print('Something went wrong when writing to the file')
finally:
    f.close()

# %%
# 11. User Input:
# Python allows for user input.
# That means we are able to ask the user for input.
# The method is a bit different in Python 3.6 than Python 2.7.
# Python 3.6 uses the input() method.
# Python 2.7 uses the raw_input() method.
# The input() method reads a line from input, converts into a string and returns it.
# The raw_input() method reads a line from input, converts into a string and returns it.

username = input('Enter username:')
print('Username is:', username)
# Out:
# Username is: puKAR

# %%
# 12. String Formatting:
# String formatting lets you inject items into a string rather than trying to chain items together using commas or string concatenation.
# As a quick comparison, consider:
player = 'Thomas'
points = 33
print('Last night, ' + player + ' scored ' + str(points) + ' points.')
# You can use string formatting to make this line a lot easier to read and write:
player = 'Thomas'
points = 33
print('Last night, %s scored %d points.' % (player, points))
# There are three ways to perform string formatting.
# The oldest method involves placeholders using the modulo % character.
# An even more convenient method uses the .format() string method.
# The newest method, introduced with Python 3.6, uses formatted string literals, called f-strings.
# Here are some examples:
player = 'Thomas'
points = 33
print('Last night, %s scored %d points.' % (player, points))
# Other examples:
a = 5
b = 10
print('Five plus ten is', a + b)
# You can basically put any Python expression inside the braces and it will be output in the string.
# Here are some examples:
name = 'John'
age = 25
print('%s is %d years old.' % (name, age))
mylist = [1, 2, 3]
print('A list: %s' % mylist)
# Here are some basic argument specifiers you should know:
# %s - String (or any object with a string representation, like numbers)
# %d - Integers
# %f - Floating point numbers
# %.<number of digits>f - Floating point numbers with a fixed amount of digits to the right of the dot.
# %x/%X - Integers in hex representation (lowercase/uppercase)
# Here are some examples:
name = 'John'
age = 25
print('Hello, %s!' % name)
print('%s is %d years old.' % (name, age))
mylist = [1, 2, 3]
print('A list: %s' % mylist)
data = ('John', 'Doe', 53.44)
format_string = 'Hello'
print('%s %s %s. Your current balance is $%s.' % (format_string, data[0], data[1], data[2]))
# Using the .format() method:
print('Hello, {}'.format('John'))
print('Hello, {}. You are {}.'.format('John', 25))
print('Hello, {}. You are {}.'.format(name, age))
print('Hello, {0}. You are {1}.'.format(name, age))
print('Hello, {1}. You are {0}.'.format(age, name))
# The .format() method has several advantages over the %s placeholder method:
# 1. You can insert objects by referring to their index, position, or key:
print('Hello, {name}. You are {age}.'.format(name='John', age=25))
person = {'name': 'John', 'age': 23}
print('Hello, {name}. You are {age}.'.format(**person))
# 2. You can use list indexing:
li = ['John', 25]
print('Hello, {0[0]}. You are {0[1]}.'.format(li))
# 3. You can use attribute access:
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
p1 = Person('John', 23)
print('Hello, {0.name}. You are {0.age}.'.format(p1))
# 4. You can use element indexing:
data = ('John', 'Doe')
print('Hello, {0[0]} {0[1]}.'.format(data))
# 5. You can format numbers:
print('The number is {:d}'.format(42))
print('The number is {:f}'.format(42))
print('The number is {:b}'.format(42))
print('The number is {:o}'.format(42))
print('The number is {:x}'.format(42))
print('The number is {:X}'.format(42))
# 6. You can format dates:
import datetime
date = datetime.datetime.now()
print('The current date and time is {:%Y-%m-%d %H:%M:%S}'.format(date))
# 7. You can format percentages:
points = 19
total = 22
print('Correct answers: {:.2%}'.format(points/total))
# 8. You can round numbers:
print('The number is {:.2f}'.format(42))
# 9. You can use the string method:
name = 'John'
print('Hello, {}'.format(name))
# 10. You can use the string method with numbers:
age = 25
print('Hello, {}'.format(age))
# 11. You can use the string method with lists:
mylist = [1, 2, 3]
print('A list: {}'.format(mylist))
# 12. You can use the string method with multiple arguments:
name = 'John'
age = 25
print('Hello, {}. You are {}.'.format(name, age))
# 13. You can use the string method with dictionaries:
person = {'name': 'John', 'age': 23}
print('Hello, {name}. You are {age}.'.format(**person))
# 14. You can use the string method with list indexing:
li = ['John', 25]
print('Hello, {0[0]}. You are {0[1]}.'.format(li))
# Out:
# Last night, Thomas scored 33 points.
# Last night, Thomas scored 33 points.
# Last night, Thomas scored 33 points.
# Five plus ten is 15
# John is 25 years old.
# A list: [1, 2, 3]
# Hello, John!
# John is 25 years old.
# A list: [1, 2, 3]
# Hello John Doe. Your current balance is $53.44.
# Hello, John
# Hello, John. You are 25.
# Hello, John. You are 25.
# Hello, John. You are 25.
# Hello, John. You are 25.
# Hello, John. You are 25.
# Hello, John. You are 23.
# Hello, John. You are 25.
# Hello, John. You are 23.
# Hello, John Doe.
# The number is 42
# The number is 42.000000
# The number is 101010
# The number is 52
# The number is 2a
# The number is 2A
# The current date and time is 2024-04-26 22:41:44
# Correct answers: 86.36%
# The number is 42.00
# Hello, John
# Hello, 25
# A list: [1, 2, 3]
# Hello, John. You are 25.
# Hello, John. You are 23.
# Hello, John. You are 25.

# %%
# 13. Regular Expressions:
# A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern.
# RegEx can be used to check if a string contains the specified search pattern.
# Python has a built-in package called re, which can be used to work with Regular Expressions.
# Import the re module:
import re
# RegEx Functions:
# The re module offers a set of functions that allows us to search a string for a match:
# findall - Returns a list containing all matches
# search - Returns a Match object if there is a match anywhere in the string
# split - Returns a list where the string has been split at each match
# sub - Replaces one or many matches with a string
# Metacharacters:
# Metacharacters are characters with a special meaning:
# [] - A set of characters
# \ - Signals a special sequence (can also be used to escape special characters)
# . - Any character (except newline character)
# ^ - Starts with
# $ - Ends with
# * - Zero or more occurrences
# + - One or more occurrences
# {} - Exactly the specified number of occurrences
# | - Either or
# () - Capture and group
# Special Sequences:
# A special sequence is a \ followed by one of the characters in the list below, and has a special meaning:
# \A - Returns a match if the specified characters are at the beginning of the string
# \b - Returns a match where the specified characters are at the beginning or at the end of a word r"ain\b"
# \B - Returns a match where the specified characters are present, but NOT at the beginning (or at the end) of a word
# \d - Returns a match where the string contains digits (numbers from 0-9)
# \D - Returns a match where the string DOES NOT contain digits
# \s - Returns a match where the string contains a white space character
# \S - Returns a match where the string DOES NOT contain a white space character

# %%
#
